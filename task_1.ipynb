# %%
pip install pandas matplotlib seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.9 kB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/110.1 kB ? eta -:--:--
#      ----------------------------------- -- 102.4/110.1 kB 3.0 MB/s eta 0:00:01
#      -------------------------------------- 110.1/110.1 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB 5.2 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/11.0 MB 3.8 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/11.0 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.0 MB 3.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/11.0 MB 3.6 MB/s eta 0:00:03
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Age Group': ['0-20 Years', '21-64 Years', '65+ Years'],
    'Population (Millions)': [512, 807, 98]
}

df = pd.DataFrame(data)

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Age Group', y='Population (Millions)', data=df, palette='pastel')
plt.title("India's Population Distribution by Age Group (2022)")
plt.xlabel("Age Group")
plt.ylabel("Population in Millions")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\saran\AppData\Local\Temp\ipykernel_9768\3565609129.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Age Group', y='Population (Millions)', data=df, palette='pastel')
